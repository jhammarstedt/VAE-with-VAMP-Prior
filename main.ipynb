# %%
from model import VanillaVAE
from load_data import load_dynamic_mnist
from torch.optim import Adam
from utils import train_vae

# %%
args = {
    'batch_size': 100,
    'input_size': [1, 28, 28],
    'epochs': 20,
    'lr': 0.0001,
}
args
# Out:
# {'batch_size': 100, 'input_size': [1, 28, 28], 'epochs': 20, 'lr': 0.0001}

# %%
train_loader, val_loader, test_loader, input_size = load_dynamic_mnist(args['batch_size'])
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/torchvision/datasets/mnist.py:58: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# (60000, 784)
# /shared-libs/python3.7/py/lib/python3.7/site-packages/torchvision/datasets/mnist.py:48: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# /shared-libs/python3.7/py/lib/python3.7/site-packages/torchvision/datasets/mnist.py:63: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /shared-libs/python3.7/py/lib/python3.7/site-packages/torchvision/datasets/mnist.py:53: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")

# %%
model = VanillaVAE(input_size=input_size[1], hidden_dims=100, latent_dims=100)
optimizer = Adam(model.parameters(), lr=args['lr'])

# %%
train_loss_history = []
train_re_history = []
train_kl_history = []

# %%
for epoch in range(1, args['epochs'] + 1):
    model, tr_loss_e, tr_re_e, tr_kl_e = train_vae(train_loader=train_loader, model=model, optimizer=optimizer)
    train_loss_history.append(tr_loss_e)
    train_re_history.append(tr_re_e)
    train_kl_history.append(tr_kl_e)
    print("Epoch {} -  loss: {:.3f}\t, reconstruction loss")
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/torch/autograd/__init__.py:132: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   allow_unreachable=True)  # allow_unreachable flag
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-469f9d811805> in <module>
#       1 for epoch in range(1, args['epochs'] + 1):
# ----> 2     model, tr_loss_e, tr_re_e, tr_kl_e = train_vae(train_loader=train_loader, model=model, optimizer=optimizer)
#       3     train_loss_history.append(tr_loss_e)
#       4     train_re_history.append(tr_re_e)
#       5     train_kl_history.append(tr_kl_e)
#
# /work/MLA_VAE_Vamp/utils.py in train_vae(train_loader, model, optimizer)
#      14
#      15         # reset gradients
# ---> 16         optimizer.zero_grad()
#      17         # loss evaluation (forward pass)
#      18         loss, RE, KL = model.get_loss(x)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/torch/optim/optimizer.py in zero_grad(self, set_to_none)
#     190                         else:
#     191                             p.grad.requires_grad_(False)
# --> 192                         p.grad.zero_()
#     193
#     194     def step(self, closure):
#
# KeyboardInterrupt:

# %%
train_re_history
# Out:
# [-8.663428793605276e+22,
#  -5.8882444530428504e+23,
#  -2.7372974083852337e+21,
#  -2.8089394221611466e+22,
#  -2.06095628145548e+22,
#  -2.8840172096993106e+23,
#  -7.863929808222158e+21,
#  -8.127808720847935e+23,
#  -2.8029935432838512e+23,
#  -3.165014165532466e+23,
#  -1.5885363783943982e+21,
#  -1.0753007223771842e+23,
#  -9.605760374666372e+23,
#  -1.7513625940322274e+22,
#  -1.6788243877331638e+22,
#  -7.42433654420306e+23,
#  -2.0917313433578046e+23,
#  -1.7641151961808646e+23,
#  -4.464574220403068e+22,
#  -5.436071732265267e+21]
